# %%
import sys

#data_dir sys.argv[1] 

# 設定檔案目錄進入點
data_dir = './'

import glob
for g1 in ['./fbank', './label', './mfcc', './phones', './48phone_char.map']:
    if g1 != './wav':
        print(g1)
        for g2 in glob.glob(g1+'/*'):
            print('\t'+g2)
# Out:
# ./fbank
# 	./fbank/train.ark
# 	./fbank/test.ark
# ./label
# 	./label/train.lab
# ./mfcc
# 	./mfcc/train.ark
# 	./mfcc/test.ark
# ./phones
# 	./phones/48_39.map
# ./48phone_char.map

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

# 設定pandas印出比較完整的內容
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# 將ark讀成pandas的DataFrame
mfcc_train = pd.DataFrame.from_csv(data_dir+'mfcc/train.ark', sep = ' ', header = None, index_col=None)
mfcc_test = pd.DataFrame.from_csv(data_dir+'mfcc/test.ark', sep = ' ', header = None, index_col=None)
# 將columns第0欄設成instanceID, 後面的1,2,3 ... 變成 mfcc_1, mfcc_2, mfcc_3
mfcc_train.columns = ['instanceID']+['mfcc_' + str(c) for c in mfcc_train.columns[1:] ]
mfcc_test.columns = ['instanceID']+['mfcc_' + str(c) for c in mfcc_test.columns[1:] ]
print('mfcc_train has,', len(mfcc_train.columns)-1, 'features,', 'mfcc_test has,', len(mfcc_test.columns)-1, 'features')

fbank_train = pd.DataFrame.from_csv(data_dir+'fbank/train.ark', sep = ' ', header = None, index_col=None)
fbank_test = pd.DataFrame.from_csv(data_dir+'fbank/test.ark', sep = ' ', header = None, index_col=None)
fbank_train.columns = ['instanceID']+['fbank_' + str(c) for c in fbank_train.columns[1:] ]
fbank_test.columns = ['instanceID']+['fbank_' + str(c) for c in fbank_test.columns[1:] ]
print('fbank_train has,', len(fbank_train.columns)-1, 'features,', 'fbank_test has,', len(fbank_test.columns)-1, 'features')
# Out:
# mfcc_train has, 39 features, mfcc_test has, 39 features
# fbank_train has, 69 features, fbank_test has, 69 features

# %%
# 將mfcc根fbank合併(相同row的columns合併)
mfcc_fbank_train = pd.merge(mfcc_train, fbank_train, on='instanceID')
mfcc_fbank_test = pd.merge(mfcc_test, fbank_test, on='instanceID')

# %%
# set column 0 as index
# 將column 'instanceID'設為index
mfcc_train.set_index('instanceID', inplace = True)
mfcc_test.set_index('instanceID', inplace = True)
fbank_train.set_index('instanceID', inplace = True)
fbank_test.set_index('instanceID', inplace = True)
mfcc_fbank_train.set_index('instanceID', inplace = True)
mfcc_fbank_test.set_index('instanceID', inplace = True)

# %%
# 分析有多少speaker、有多少sentence、有多少frames
#speakers1 = np.array([i.split('_')[0] for i in mfcc_train.index ])
#sentences1 = np.array([i.split('_')[1] for i in mfcc_train.index ])
#frames1 = np.array([int(i.split('_')[2]) for i in mfcc_train.index ])

#speakers2 = np.array([i.split('_')[0] for i in mfcc_test.index ])
#sentences2 = np.array([i.split('_')[1] for i in mfcc_test.index ])
#frames2 = np.array([int(i.split('_')[2]) for i in mfcc_test.index ])

#print('there are {} / {} frames in training/testing data'.format(len(mfcc_train.index), len(mfcc_test.index)))
#print('there are {} / {} speakers in training/testing data'.format(len(pd.unique(sentences1)), len(pd.unique(sentences2)))) 
#print('there are {} / {} max frames in training/testing data'.format(frames1.max(), frames2.max())) 
print('there are 1124823 / 180406 frames in training/testing data')
print('there are 1716 / 342 speakers in training/testing data')
print('there are 777 / 742 max frames in training/testing data')
# Out:
# there are 1124823 / 180406 frames in training/testing data
# there are 1716 / 342 speakers in training/testing data
# there are 777 / 742 max frames in training/testing data

# %%
# multi-index version
# 將index用'_'切字串，並設為三層的index
index = [np.array([i.split('_')[0] for i in mfcc_train.index ]),
         np.array([i.split('_')[1] for i in mfcc_train.index ]),
         np.array([i.split('_')[2] for i in mfcc_train.index ]),]
mfcc_train_multi_index = mfcc_train.set_index(index)

index = [np.array([i.split('_')[0] for i in mfcc_test.index ]),
         np.array([i.split('_')[1] for i in mfcc_test.index ]),
         np.array([i.split('_')[2] for i in mfcc_test.index ]),]
mfcc_test_multi_index = mfcc_test.set_index(index)

index = [np.array([i.split('_')[0] for i in fbank_train.index ]),
         np.array([i.split('_')[1] for i in fbank_train.index ]),
         np.array([i.split('_')[2] for i in fbank_train.index ]),]
fbank_train_multi_index = fbank_train.set_index(index)

index = [np.array([i.split('_')[0] for i in fbank_test.index ]),
         np.array([i.split('_')[1] for i in fbank_test.index ]),
         np.array([i.split('_')[2] for i in fbank_test.index ]),]
fbank_test_multi_index = fbank_test.set_index(index)

index = [np.array([i.split('_')[0] for i in mfcc_fbank_train.index ]),
         np.array([i.split('_')[1] for i in mfcc_fbank_train.index ]),
         np.array([i.split('_')[2] for i in mfcc_fbank_train.index ]),]
mfcc_fbank_train_multi_index = mfcc_fbank_train.set_index(index)

index = [np.array([i.split('_')[0] for i in mfcc_fbank_test.index ]),
         np.array([i.split('_')[1] for i in mfcc_fbank_test.index ]),
         np.array([i.split('_')[2] for i in mfcc_fbank_test.index ]),]
mfcc_fbank_test_multi_index = mfcc_fbank_test.set_index(index)

# %%
#將每個sentence的所有frame綁成一個，沒做padding
def sequence_no_padding(df):
    multi_index = pd.unique([ (mi[0], mi[1]) for mi in df.index ])
    nopadding = list()
    for mi in multi_index:
        nopadding.append(df.ix[mi].as_matrix())
    
    return np.asarray(nopadding)

mfcc_train_nopadding = sequence_no_padding(mfcc_train_multi_index)
mfcc_test_nopadding = sequence_no_padding(mfcc_test_multi_index)
fbank_train_nopadding = sequence_no_padding(fbank_train_multi_index)
fbank_test_nopadding = sequence_no_padding(fbank_test_multi_index)
mfcc_fbank_train_nopadding = sequence_no_padding(mfcc_fbank_train_multi_index)
mfcc_fbank_test_nopadding = sequence_no_padding(mfcc_fbank_test_multi_index)
# Out:
# /home/bonzo/anaconda3/envs/python3.5bk/lib/python3.5/site-packages/ipykernel/__main__.py:5: PerformanceWarning: indexing past lexsort depth may impact performance.

# %%
#直接將dtataframe轉成ndarray，把句子當成連續的東西處理,但看起來效果不是很好
#mfcc_train_nopadding2 = mfcc_train_multi_index.as_matrix()
#mfcc_test_nopadding2 = mfcc_test_multi_index.as_matrix()
#fbank_train_nopadding2 = fbank_train_multi_index.as_matrix()
#fbank_test_nopadding2 = fbank_test_multi_index.as_matrix()
#mfcc_fbank_train_nopadding2 = mfcc_fbank_train_multi_index.as_matrix()
#mfcc_fbank_test_nopadding2 = mfcc_fbank_test_multi_index.as_matrix()

# %%
#按照前兩個index去做padding，由於最長句子是777直接填777
def sequence_padding(df, max_length, dim, zero=0):
    multi_index = pd.unique([ (mi[0], mi[1]) for mi in df.index ])
    padding = list()
    for mi in multi_index:
        m = df.ix[mi].as_matrix()
        b = np.array([zero]*dim)
        
        while m.shape[0] < max_length:
            b = b.reshape(1, dim)
            m = np.concatenate((m, b), axis=0)
        else:
            padding.append(m)
    
    return np.asarray(padding)

mfcc_train_padding = sequence_padding(mfcc_train_multi_index, 777, 39)
mfcc_test_padding = sequence_padding(mfcc_test_multi_index, 777, 39)
fbank_train_padding = sequence_padding(fbank_train_multi_index, 777, 69)
fbank_test_padding = sequence_padding(fbank_test_multi_index, 777, 69)
mfcc_fbank_train_padding = sequence_padding(mfcc_fbank_train_multi_index, 777, 108)
mfcc_fbank_test_padding = sequence_padding(mfcc_fbank_test_multi_index, 777, 108)
# Out:
# /home/bonzo/anaconda3/envs/python3.5bk/lib/python3.5/site-packages/ipykernel/__main__.py:5: PerformanceWarning: indexing past lexsort depth may impact performance.

# %%
# Out:
# (3696, 777, 39)

# %%
#直接機將所有訊號當成連續的，平均frame數量是304，將每個都切成304(只有最後一個不足304捕到304筆)，但效果很差(不確定有沒有處理正確)
def slice_padding(df, dim, zero=0, slice_num = 304):
    df = df.as_matrix()
    padding = list()
    b = np.array([zero]*dim)
    b = b.reshape(1, dim)
    print(b.shape)
    
    for sta in list(range(0, df.shape[0], slice_num)):
        if sta+slice_num > df.shape[0]:
            m = df[sta:]
            while m.shape[0] < slice_num:
                m = np.concatenate((m, b), axis=0)
        else:
            m = df[sta:sta+slice_num]
        
        padding.append(m)
    return np.asarray(padding)

mfcc_train_304 = slice_padding(mfcc_train, dim = 39)
mfcc_test_304 = slice_padding(mfcc_test, dim = 39)
fbank_train_304 = slice_padding(fbank_train, dim = 69)
fbank_test_304 = slice_padding(fbank_test, dim = 69)
mfcc_fbank_train_304 = slice_padding(mfcc_fbank_train, dim = 108)
mfcc_fbank_test_304 = slice_padding(mfcc_fbank_test, dim = 108)
# Out:
# (1, 39)
# (1, 39)
# (1, 69)
# (1, 69)
# (1, 108)
# (1, 108)

# %%
# 處理mapping之間的轉換
# phone_to_number是48個pnohne對到48個數字
# number_to_phone上面的inversion mapping
# number_to_char 48個數字map到char
# number_40_to_char_39 則是直接將48個輸出對應到39個字母

with open(data_dir+'48phone_char.map') as phone_map:
    phone_to_number = dict()
    number_to_phone = dict()
    number_to_char = dict()
    for pm in phone_map:
        (a, b, c) = pm.replace('\n','').split('\t')
        phone_to_number[a] = int(b)
        number_to_phone[int(b)] = a
        number_to_char[int(b)] = c
        
with open(data_dir+'phones/48_39.map') as phone_map:
    phone_48_to_39 = dict()
    for pm in phone_map:
        (a, b) = pm.replace('\n','').split('\t')
        phone_48_to_39[a] = b  
        
number_48_to_39 = dict()
number_48_to_char_39 = dict()
for n48, v48 in number_to_phone.items():
    v39 = phone_48_to_39[v48]
    n39 = phone_to_number[v39]
    c = number_to_char[n39]
    #print(n48, v48, v39, n39, c)
    number_48_to_39[n48] = n39
    number_48_to_char_39[n48] = c

# %%
# 處理最後output用的，將重複tag拿掉
def compact(list_in):
    #list_out = list()
    e0 = list_in[0]
    list_out = [e0]
    for e1 in list_in[1:]:
        if e1 == e0:
            continue
        else:
            e0 = e1
            list_out.append(e0)
        
    return list_out

# 處理最後output用的，將頭尾sil去掉，重複的tag拿掉，並轉為字母
def out_csv(pred, prefix):
    sample = pd.DataFrame.from_csv('sample.csv')
    test_index = list(sample.index)
    with open(prefix+'.csv', 'w') as csv:
        
        csv.write('id,phone_sequence\n')
        for p, t in zip(pred, test_index):
            pc = compact(p)
            if pc[0] == 37:
                del pc[0]
            if pc [-1] == 37:
                del pc[-1]
            #print(''.join([number_48_to_char_39[x] for x in pc]))
            csv.write(t+','+''.join([number_48_to_char_39[x] for x in pc])+'\n')

# %%
# Out:
# 17

# %%
# 處理y，前面的步驟跟處理其他的一樣
train_y = pd.DataFrame.from_csv(data_dir+"label/train.lab", header=None, index_col=None)          
train_y.ix[:,1] = pd.Series([ phone_to_number[p] for p in train_y.ix[:,1]])
train_y.columns = ['instanceID', 'label']
train_y.set_index('instanceID', inplace = True)
index = [np.array([i.split('_')[0] for i in train_y.index ]),
         np.array([i.split('_')[1] for i in train_y.index ]),
         np.array([i.split('_')[2] for i in train_y.index ]),]
train_y_multi_index = train_y.set_index(index)
# reorder train_y
# y的順序跟training data不同，將y改成跟training data一樣的次序
train_y_multi_index = train_y_multi_index.ix[mfcc_train_multi_index.index]
train_y_padding = sequence_padding(train_y_multi_index, 777, 1, zero=37)

# %%
# 要先將y重排，然後再切成304等分
train_y_reorder = train_y.ix[mfcc_train.index]
train_y_304 = slice_padding(train_y_reorder, dim=1, zero=37, slice_num = 304)
train_y_304_categorical = list()
for s in train_y_304:
    c = keras.utils.to_categorical(s, num_classes=48)
    train_y_304_categorical.append(c)
else:
    train_y_304_categorical = np.asarray(train_y_304_categorical)
# Out:
# (1, 1)

# %%
# Out:
# 1.0

# %%
import pickle
pickle.dump(mfcc_train, open("mfcc_train.pkl",'wb'))
pickle.dump(mfcc_test, open("mfcc_test.pkl",'wb'))
pickle.dump(fbank_train, open("fbank_train.pkl",'wb'))
pickle.dump(fbank_test, open("fbank_train.pkl",'wb'))
pickle.dump(mfcc_fbank_train, open("mfcc_fbank_train.pkl",'wb'))
pickle.dump(mfcc_fbank_test, open("mfcc_fbank_test.pkl",'wb'))

pickle.dump(mfcc_train_nopadding, open("mfcc_train_nopadding.pkl",'wb'))
pickle.dump(mfcc_test_nopadding, open("mfcc_test_nopadding.pkl",'wb'))
pickle.dump(fbank_train_nopadding, open("fbank_train_nopadding.pkl",'wb'))
pickle.dump(fbank_test_nopadding, open("fbank_test_nopadding.pkl",'wb'))
pickle.dump(mfcc_fbank_train_nopadding, open("mfcc_fbank_train_nopadding.pkl",'wb'))
pickle.dump(mfcc_fbank_test_nopadding, open("mfcc_fbank_test_nopadding.pkl",'wb'))

pickle.dump(mfcc_train_padding, open("mfcc_train_padding.pkl",'wb'))
pickle.dump(mfcc_test_padding, open("mfcc_test_padding.pkl",'wb'))
pickle.dump(fbank_train_padding, open("fbank_train_padding.pkl",'wb'))
pickle.dump(fbank_test_padding, open("fbank_test_padding.pkl",'wb'))
pickle.dump(mfcc_fbank_train_padding, open("mfcc_fbank_train_padding.pkl",'wb'))
pickle.dump(mfcc_fbank_test_padding, open("mfcc_fbank_test_padding.pkl",'wb'))

pickle.dump(train_y_padding, open("train_y_padding.pkl", 'wb'))

# %%
pickle.dump(mfcc_train_nopadding2, open("mfcc_train_nopadding2.pkl",'wb'))
pickle.dump(mfcc_test_nopadding2, open("mfcc_test_nopadding2.pkl",'wb'))
pickle.dump(fbank_train_nopadding2, open("fbank_train_nopadding2.pkl",'wb'))
pickle.dump(fbank_test_nopadding2, open("fbank_test_nopadding2.pkl",'wb'))
pickle.dump(mfcc_fbank_train_nopadding2, open("mfcc_fbank_train_nopadding2.pkl",'wb'))
pickle.dump(mfcc_fbank_test_nopadding2, open("mfcc_fbank_test_nopadding2.pkl",'wb'))

# %%
import pickle
mfcc_train = pickle.load(open("mfcc_train.pkl",'rb'))
mfcc_test = pickle.load(open("mfcc_test.pkl",'rb'))
fbank_train = pickle.load(open("fbank_train.pkl",'rb'))
fbank_test = pickle.load(open("fbank_train.pkl",'rb'))
mfcc_fbank_train = pickle.load(open("mfcc_fbank_train.pkl",'rb'))
mfcc_fbank_test = pickle.load(open("mfcc_fbank_test.pkl",'rb'))

mfcc_train_nopadding = pickle.load(open("mfcc_train_nopadding.pkl",'rb'))
mfcc_test_nopadding = pickle.load(open("mfcc_test_nopadding.pkl",'rb'))
fbank_train_nopadding = pickle.load(open("fbank_train_nopadding.pkl",'rb'))
fbank_test_nopadding = pickle.load(open("fbank_test_nopadding.pkl",'rb'))
mfcc_fbank_train_nopadding = pickle.load(open("mfcc_fbank_train_nopadding.pkl",'rb'))
mfcc_fbank_test_nopadding = pickle.load(open("mfcc_fbank_test_nopadding.pkl",'rb'))

mfcc_train_padding = pickle.load(open("mfcc_train_padding.pkl",'rb'))
mfcc_test_padding = pickle.load(open("mfcc_test_padding.pkl",'rb'))
fbank_train_padding = pickle.load(open("fbank_train_padding.pkl",'rb'))
fbank_test_padding = pickle.load(open("fbank_test_padding.pkl",'rb'))
mfcc_fbank_train_padding = pickle.load(open("mfcc_fbank_train_padding.pkl",'rb'))
mfcc_fbank_test_padding = pickle.load(open("mfcc_fbank_test_padding.pkl",'rb'))

train_y_padding = pickle.load(open("train_y_padding.pkl", 'rb'))

# %%
#mfcc_train_nopadding2 = pickle.load(open("mfcc_train_nopadding2.pkl",'rb'))
#mfcc_test_nopadding2 = pickle.load(open("mfcc_test_nopadding2.pkl",'rb'))
#fbank_train_nopadding2 = pickle.load(open("fbank_train_nopadding2.pkl",'rb'))
#fbank_test_nopadding2 = pickle.load(open("fbank_test_nopadding2.pkl",'rb'))
#mfcc_fbank_train_nopadding2 = pickle.load(open("mfcc_fbank_train_nopadding2.pkl",'rb'))
#mfcc_fbank_test_nopadding2 = pickle.load(open("mfcc_fbank_test_nopadding2.pkl",'rb'))

# %%
# Out:
# 17

# %%
import keras

train_y_padding_categorical = list()
for s in train_y_padding:
    c = keras.utils.to_categorical(s, num_classes=48)
    train_y_padding_categorical.append(c)
else:
    train_y_padding_categorical = np.asarray(train_y_padding_categorical)
# Out:
# Using TensorFlow backend.

# %%
"""
# expected input data shape: (batch_size, timesteps, data_dim)
model = Sequential()
model.add(LSTM(32, return_sequences=True,
               input_shape=(timesteps, data_dim)))  # returns a sequence of vectors of dimension 32
model.add(LSTM(32, return_sequences=True))  # returns a sequence of vectors of dimension 32
model.add(LSTM(32))  # return a single vector of dimension 32
model.add(Dense(10, activation='softmax'))
"""
# Out:
# "\n# expected input data shape: (batch_size, timesteps, data_dim)\nmodel = Sequential()\nmodel.add(LSTM(32, return_sequences=True,\n               input_shape=(timesteps, data_dim)))  # returns a sequence of vectors of dimension 32\nmodel.add(LSTM(32, return_sequences=True))  # returns a sequence of vectors of dimension 32\nmodel.add(LSTM(32))  # return a single vector of dimension 32\nmodel.add(Dense(10, activation='softmax'))\n"

# %%
import keras

import numpy as np
import keras.backend as K 
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import GRU
from keras.layers import LSTM, Bidirectional
from keras.layers.embeddings import Embedding
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint

from keras import metrics
from sklearn.model_selection import StratifiedKFold

from pylab import *

# %%
from sklearn.model_selection import KFold
dim = 3696
kf = KFold(n_splits=5, random_state = 1)
kfold = [ (train, valid) for train, valid in kf.split( list(range(dim)))]

# %%
# for 304
dim = 3701
kf1 = list(range(0          , 3701//5 * 1))
kf2 = list(range(3701//5 * 1, 3701//5 * 2))
kf3 = list(range(3701//5 * 2, 3701//5 * 3))
kf4 = list(range(3701//5 * 3, 3701//5 * 4))
kf5 = list(range(3701//5 * 4, 3701       ))

kfold = [(np.array(kf2+kf3+kf4+kf5), np.array(kf1)), 
         (np.array(kf1+kf3+kf4+kf5), np.array(kf2)),
         (np.array(kf1+kf2+kf4+kf5), np.array(kf3)),
         (np.array(kf1+kf2+kf3+kf5), np.array(kf4)),
         (np.array(kf1+kf2+kf3+kf4), np.array(kf5))]

# %%
optimizer = ['sgd', 'adagrad', 'adadelta', 'adam', 'adamax', 'nadam', 'rmsprop']
optimizer = ['sgd', 'nadam']
rnn = ['LSTM', 'LSTMs', 'BiLSTM', 'GRU']
data = ['mfcc', 'fbank', 'mfcc_bank', 'mfccnp', 'fbanknp', 'mfcc_banknp']
data = ['mfcc', 'fbank', 'mfcc_bank', ]
setting = [(op, r, d) for op in optimizer for r in rnn for d in data]
setting = [('LSTM', 'nadam', d)  for d in data]
setting = [('LSTM', 'nadam', 'mfcc_fbank')]
setting = [('LSTM_state', 'nadam', 'mfcc_304')]
setting = [('BiLSTM', 'nadam', 'mfcc_fbank')]

sample_length = 777
#sample_length = 304

for s in setting:
    cfg_model, cfg_opt, cfg_data = s 
    prefix = '_'.join(s)
    print('setting: ', s)

    for t, v in kfold:
        if cfg_data == 'mfcc':
            x_train, x_valid = mfcc_train_padding[t], mfcc_train_padding[v]
            test = mfcc_test_padding
            test_index = [np.array([i.split('_')[0] for i in mfcc_test.index ]),
                          np.array([i.split('_')[1] for i in mfcc_test.index ]),
                          np.array([i.split('_')[2] for i in mfcc_test.index ]),]
            
            test_index = [ (test_index[0][i], test_index[1][i], test_index[2][i]) for i in range(sample_length)]
            dim = 39
            y_train, y_valid = train_y_padding_categorical[t], train_y_padding_categorical[v]
        elif cfg_data == 'fbank':
            x_train, x_valid = fbank_train_padding[t], fbank_train_padding[v]
            test = fbank_test_padding
            test_index = [np.array([i.split('_')[0] for i in fbank_test.index ]),
                          np.array([i.split('_')[1] for i in fbank_test.index ]),
                          np.array([i.split('_')[2] for i in fbank_test.index ]),]
            test_index = [ (test_index[0][i], test_index[1][i], test_index[2][i]) for i in range(sample_length)]
            dim = 69
            y_train, y_valid = train_y_padding_categorical[t], train_y_padding_categorical[v]
        elif cfg_data == 'mfcc_fbank':
            x_train, x_valid = mfcc_fbank_train_padding[t], mfcc_fbank_train_padding[v]
            test = mfcc_fbank_test_padding
            test_index = [np.array([i.split('_')[0] for i in mfcc_fbank_test.index ]),
                          np.array([i.split('_')[1] for i in mfcc_fbank_test.index ]),
                          np.array([i.split('_')[2] for i in mfcc_fbank_test.index ]),]
            test_index = [ (test_index[0][i], test_index[1][i], test_index[2][i]) for i in range(sample_length)]
            dim = 108
            y_train, y_valid = train_y_padding_categorical[t], train_y_padding_categorical[v]
        elif cfg_data == 'mfcc_304':
            x_train, x_valid = mfcc_train_304[t], mfcc_train_304[v]
            test = mfcc_test_304
            test_index = [np.array([i.split('_')[0] for i in mfcc_test.index ]),
                          np.array([i.split('_')[1] for i in mfcc_test.index ]),
                          np.array([i.split('_')[2] for i in mfcc_test.index ]),]
            test_index = [ (test_index[0][i], test_index[1][i], test_index[2][i]) for i in range(sample_length)]
            dim = 39
            y_train, y_valid = train_y_304_categorical[t], train_y_304_categorical[v]
        
    else:
        print('done!!')
    
    if True:
        if cfg_model == "LSTM":
            model = Sequential()
            model.add(LSTM(64, return_sequences=True, activation='sigmoid', dropout=0.25, input_shape=(sample_length, dim)))
            model.add(Dense(256,activation='sigmoid'))
            model.add(Dropout(0.25))
            model.add(Dense(64,activation='sigmoid'))
            model.add(Dropout(0.25))
            model.add(Dense(48,activation='softmax'))
            model.summary()
        if cfg_model == "BiLSTM":
            model = Sequential()
            model.add(Bidirectional(LSTM(64, 
                                     return_sequences=True, 
                                     activation='sigmoid', 
                                     dropout=0.25), input_shape=(sample_length, dim))
                     )
            model.add(Dense(256,activation='sigmoid'))
            model.add(Dropout(0.25))
            model.add(Dense(64,activation='sigmoid'))
            model.add(Dropout(0.25))
            model.add(Dense(48,activation='softmax'))
            model.summary()                
        elif cfg_model == "LSTMs":
            model = Sequential()
            model.add(LSTM(64, return_sequences=True, activation='sigmoid', dropout=0.25, input_shape=(sample_length, dim)))
            model.add(LSTM(48, return_sequences=True, activation='sigmoid', dropout=0.25))
            model.add(Dense(48,activation='softmax'))
            model.summary()     
        elif cfg_model == "GRU":
            model = Sequential()
            model.add(GRU(64, return_sequences=True, activation='sigmoid', dropout=0.25, input_shape=(sample_length, dim)))
            model.add(Dense(256,activation='sigmoid'))
            model.add(Dropout(0.25))
            model.add(Dense(64,activation='sigmoid'))
            model.add(Dropout(0.25))
            model.add(Dense(48,activation='softmax'))
            model.summary() 
        elif cfg_model == "LSTM_state":
            model = Sequential()
            model.add(LSTM(
                64,
                batch_input_shape=(1, 304, dim),
                return_sequences=True, 
                activation='sigmoid', 
                stateful = True, 
                dropout=0.25, input_shape=(sample_length, dim)))
            model.add(Dense(256,activation='sigmoid'))
            model.add(Dropout(0.25))
            model.add(Dense(64,activation='sigmoid'))
            model.add(Dropout(0.25))
            model.add(Dense(48,activation='softmax'))
            model.summary()     
        
        model.compile(loss='categorical_crossentropy',
                      optimizer=cfg_opt,
                      metrics=['accuracy'])
   
        earlystopping = EarlyStopping(monitor='val_loss', patience = 20, verbose=1, mode='min')
        checkpoint = ModelCheckpoint(filepath=prefix+'_best.hdf5',
                                 verbose=1,
                                 save_best_only=True,
                                 save_weights_only=True,
                                 monitor='val_loss',
                                 mode='min')
        mhist = model.fit(x_train, y_train, 
                     validation_data=(x_valid, y_valid),
                     epochs=500, 
                     batch_size=64,
                     verbose=1,
                     callbacks=[earlystopping, checkpoint])

    
    
    
        figure(1, figsize=(6, 6))
        plot(mhist.history['val_acc'])
        plot(mhist.history['acc'])
        savefig(prefix+'acc'+".png")
        show()

        figure(2, figsize=(6, 6))
        plot(mhist.history['val_loss'])
        plot(mhist.history['loss'])
        savefig(prefix+'loss'+".png")
        show()
    

        #y_pred = model.predict(test)
        y_pred = model.predict_classes(test, batch_size=64, verbose=1)
        print('writing ', prefix+'_y_pred.pkl')
        pickle.dump(y_pred, open(prefix+'_y_pred.pkl', 'wb'))
    
        out_csv(y_pred, 'valacc_{:.4f}'.format(max(mhist.history['val_acc'])) + prefix)
# Out:
# setting:  ('BiLSTM', 'nadam', 'mfcc_fbank')
# done!!
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_7 (Bidirection (None, 777, 128)          88576
# _________________________________________________________________
# dense_22 (Dense)             (None, 777, 256)          33024
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 777, 256)          0
# _________________________________________________________________
# dense_23 (Dense)             (None, 777, 64)           16448
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 777, 64)           0
# _________________________________________________________________
# dense_24 (Dense)             (None, 777, 48)           3120
# =================================================================
# Total params: 141,168
# Trainable params: 141,168
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2957 samples, validate on 739 samples
# Epoch 1/500
# Epoch 00000: val_loss improved from inf to 1.50929, saving model to BiLSTM_nadam_mfcc_fbank_best.hdf5
# 2957/2957 [==============================] - 88s - loss: 2.0232 - acc: 0.6043 - val_loss: 1.5093 - val_acc: 0.6469
# Epoch 2/500
# Epoch 00001: val_loss improved from 1.50929 to 1.33304, saving model to BiLSTM_nadam_mfcc_fbank_best.hdf5
# 2957/2957 [==============================] - 83s - loss: 1.4319 - acc: 0.6519 - val_loss: 1.3330 - val_acc: 0.6551
# Epoch 3/500
# Epoch 00002: val_loss improved from 1.33304 to 1.25033, saving model to BiLSTM_nadam_mfcc_fbank_best.hdf5
# 2957/2957 [==============================] - 83s - loss: 1.3186 - acc: 0.6644 - val_loss: 1.2503 - val_acc: 0.6738
# Epoch 4/500
# Epoch 00003: val_loss improved from 1.25033 to 1.18703, saving model to BiLSTM_nadam_mfcc_fbank_best.hdf5
# 2957/2957 [==============================] - 83s - loss:
val_loss did not improve
# 2957/2957 [==============================] - 81s - loss: 0.4589 - acc: 0.8592 - val_loss: 0.4135 - val_acc: 0.8694
# Epoch 267/500
# Epoch 00266: val_loss did not improve
# 2957/2957 [==============================] - 81s - loss: 0.4569 - acc: 0.8598 - val_loss: 0.3965 - val_acc: 0.8751
# Epoch 268/500
# Epoch 00267: val_loss did not improve
# 2957/2957 [==============================] - 81s - loss: 0.4583 - acc: 0.8596 - val_loss: 0.3987 - val_acc: 0.8738
# Epoch 269/500
# Epoch 00268: val_loss did not improve
# 2957/2957 [==============================] - 82s - loss: 0.4562 - acc: 0.8601 - val_loss: 0.4010 - val_acc: 0.8730
# Epoch 270/500
# Epoch 00269: val_loss did not improve
# 2957/2957 [==============================] - 81s - loss: 0.4566 - acc: 0.8596 - val_loss: 0.4007 - val_acc: 0.8734
# Epoch 271/500
# Epoch 00270: val_loss did not improve
# 2957/2957 [==============================] - 82s - loss: 0.4548 - acc: 0.8601 - val_loss: 0.4499 - val_acc: 0.8590
# Epoch 272/500
# Epoch 00271: val_loss did not improve
# 2957/2957 [==============================] - 81s - loss: 0.4628 - acc: 0.8584 - val_loss: 0.3974 - val_acc: 0.8743
# Epoch 273/500
# Epoch 00272: val_loss did not improve
# 2957/2957 [==============================] - 81s - loss: 0.4539 - acc: 0.8607 - val_loss: 0.4046 - val_acc: 0.8724
# Epoch 274/500
# Epoch 00273: val_loss did not improve
# 2957/2957 [==============================] - 81s - loss: 0.4541 - acc: 0.8605 - val_loss: 0.3975 - val_acc: 0.8739
# Epoch 275/500
# Epoch 00274: val_loss did not improve
# 2957/2957 [==============================] - 81s - loss: 0.4540 - acc: 0.8610 - val_loss: 0.4003 - val_acc: 0.8741
# Epoch 276/500
#  256/2957 [=>............................] - ETA: 69s - loss: 0.4655 - acc: 0.8585

# %%
# 下面是暫存區，沒用到

# %%
out_csv(y_pred, 'valacc_{:.4f}'.format(max(mhist.history['val_acc'])) + prefix)

# %%
out_csv(y_pred, 'valacc_{:.4f}'.format(max(mhist.history['val_acc'])) + prefix)

# %%
y_pred = pickle.load(open('LSTM_nadam_mfcc_y_pred.pkl', 'rb'))

# %%
prefix
# Out:
# 'LSTM_nadam_mfcc'

# %%
    #adam = Adam(lr=0.001,decay=1e-6,clipvalue=0.5)
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy', metrics.categorical_accuracy])
   
    earlystopping = EarlyStopping(monitor='categorical_crossentropy', patience = 15, verbose=1, mode='min')
    checkpoint = ModelCheckpoint(filepath=postfix+'_best.hdf5',
                                 verbose=1,
                                 save_best_only=True,
                                 save_weights_only=True,
                                 monitor='categorical_crossentropy',
                                 mode='min')
    mhist = model.fit(X_train, Y_train, 
                     validation_data=(X_val, Y_val),
                     epochs=nb_epoch, 
                     batch_size=batch_size,
                     verbose=1,
                     callbacks=[earlystopping,checkpoint])
    
    output_path = get_csv_name(mhist.history, postfix)
    
    
    
    figure(1, figsize=(6, 6))
    plot(mhist.history['val_f1_score'])
    plot(mhist.history['f1_score'])
    savefig(output_path+'f1'+".png")
    show()

    figure(2, figsize=(6, 6))
    plot(mhist.history['val_loss'])
    plot(mhist.history['loss'])
    savefig(output_path+'loss'+".png")
    show()
    

    Y_pred = model.predict(test_sequences)
    thresh = 0.47

# %%
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          validation_data=(x_test, y_test))

# %%
test = [(rt, rl, ac, dr)  for rt in ['GRU'] for ac in ['tanh'] for dr in [0.2, 0.5] for rl in [384, 512]]
print(test)
rnn_type = 'LSTM'
rnn_layer = 128
act = 'sigmoid'
drop = 0.1
thresh = 0.47


for t in test:
    print(t)
    (rnn_type, rnn_layer, act, drop) = t
    postfix = rnn_type+"_"+str(rnn_layer)+"_"+act+"_drop_out"+str(drop)+"thresh_"+str(thresh)+"new9"


    ### build model
    print ('Building model.')
    model = Sequential()
    model.add(Embedding(num_words,
                        embedding_dim,
                        weights=[embedding_matrix],
                        input_length=max_article_length,
                        trainable=False))
    
#    model.add(GRU(128,activation='tanh',dropout=0.1))    
    if rnn_type == 'LSTM':
        model.add(LSTM(rnn_layer,activation=act,dropout=drop))
        
    if rnn_type == 'GRU':
        model.add(GRU(rnn_layer,activation=act,dropout=drop))

    #model.add(GRU(256,activation='tanh',dropout=0.5))
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(38,activation='sigmoid'))
    model.summary()

    adam = Adam(lr=0.001,decay=1e-6,clipvalue=0.5)
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=[f1_score])
   
    earlystopping = EarlyStopping(monitor='val_f1_score', patience = 10, verbose=1, mode='max')
    checkpoint = ModelCheckpoint(filepath=postfix+'_best.hdf5',
                                 verbose=1,
                                 save_best_only=True,
                                 save_weights_only=True,
                                 monitor='val_f1_score',
                                 mode='max')
    mhist = model.fit(X_train, Y_train, 
                     validation_data=(X_val, Y_val),
                     epochs=nb_epoch, 
                     batch_size=batch_size,
                     verbose=1,
                     callbacks=[earlystopping,checkpoint])
    
    output_path = get_csv_name(mhist.history, postfix)
    
    
    
    figure(1, figsize=(6, 6))
    plot(mhist.history['val_f1_score'])
    plot(mhist.history['f1_score'])
    savefig(output_path+'f1'+".png")
    show()

    figure(2, figsize=(6, 6))
    plot(mhist.history['val_loss'])
    plot(mhist.history['loss'])
    savefig(output_path+'loss'+".png")
    show()
    

    Y_pred = model.predict(test_sequences)
    thresh = 0.47
#    with open(output_path,'w') as output:
#        print ('\"id\",\"tags\"',file=output)
#        Y_pred_thresh = (Y_pred > thresh).astype('int')
#        for index,labels in enumerate(Y_pred_thresh):
#            labels = [tag_list[i] for i,value in enumerate(labels) if value==1 ]
#            if not labels:
#                
#            labels_original = ' '.join(labels)
#            print ('\"%d\",\"%s\"'%(index,labels_original),file=output)

            
##    with open(output_path,'w') as output:
##        print ('\"id\",\"tags\"',file=output)
##        Y_pred_thresh = (Y_pred > thresh).astype('int')
##        for index,labels in enumerate(Y_pred_thresh):
##            labels = [tag_list[i] for i,value in enumerate(labels) if value==1 ]
##            #if not labels:
##                
##            labels_original = ' '.join(labels)
##            print ('\"%d\",\"%s\"'%(index,labels_original),file=output)
            
            
    with open(output_path,'w') as output:
        print ('\"id\",\"tags\"',file=output)
        #Y_pred_thresh = (Y_pred > thresh).astype('int')
        for index,labels in enumerate(Y_pred):
            labelss = [ tag_list[i] for i, value in enumerate(labels) if value > thresh]
            if not labelss:
                labelss = [tag_list[labels.argmax()]]
                
            
            #labels = [tag_list[i] for i,value in enumerate(labels) if value==1 ]
            labels_original = ' '.join(labelss)
            print ('\"%d\",\"%s\"'%(index,labels_original),file=output)


            
            
#if __name__=='__main__':
#    main()
